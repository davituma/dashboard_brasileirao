# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_br = pd.read_csv('campeonato-brasileiro-full.csv')
df_br.tail()
# Out:
#         ID  rodata        data   hora    mandante      visitante  \
# 8780  8783      38  08/12/2024  16:04      Cuiaba          Vasco
# 8781  8784      38  08/12/2024  16:04   Palmeiras     Fluminense
# 8782  8776      38  08/12/2024  16:05   Fortaleza  Internacional
# 8783  8780      38  08/12/2024  16:05  Bragantino       Criciuma
# 8784  8785      38  08/12/2024  16:05      Gremio    Corinthians
#
#      formacao_mandante formacao_visitante     tecnico_mandante  \
# 8780             4-3-3            4-3-2-1            B. Franco
# 8781           4-2-3-1            4-2-3-1  A. Moreira Ferreira
# 8782           4-2-3-1          4-1-2-1-2           J. Vojvoda
# 8783           4-2-3-1          4-1-2-1-2            F. Seabra
# 8784             4-4-2            4-3-1-2        Renato Gaúcho
#
#          tecnico_visitante     vencedor            arena  mandante_Placar  \
# 8780           F. Loureiro        Vasco   Arena Pantanal                1
# ...

# %%
df_br['data'] = pd.to_datetime(df_br['data'], format='%d/%m/%Y')

df_br = df_br[df_br['data'].dt.year >= 2010].copy()

df_br.head()
# Out:
#         ID  rodata       data   hora     mandante  visitante  \
# 3086  3087       1 2010-05-08  18:30  Botafogo-RJ     Santos
# 3087  3088       1 2010-05-08  18:30  Atletico-GO     Gremio
# 3088  3089       1 2010-05-08  18:30    Palmeiras    Vitoria
# 3089  3090       1 2010-05-09  16:00     Flamengo  Sao Paulo
# 3090  3091       1 2010-05-09  16:00  Atletico-MG      Vasco
#
#      formacao_mandante formacao_visitante tecnico_mandante tecnico_visitante  \
# 3086               NaN                NaN              NaN               NaN
# 3087               NaN                NaN              NaN               NaN
# 3088               NaN                NaN              NaN               NaN
# 3089               NaN                NaN              NaN               NaN
# 3090               NaN                NaN              NaN               NaN
#
#          vencedor               arena  mandante_Placar  visitante_Placar  \
# ...

# %%
df_br['vencedor'].unique()
#traço é empate
# Out:
# array(['-', 'Palmeiras', 'Atletico-MG', 'Cruzeiro', 'Corinthians',
#        'Ceara', 'Guarani', 'Avai', 'Fluminense', 'Gremio Prudente',
#        'Botafogo-RJ', 'Internacional', 'Santos', 'Sao Paulo', 'Flamengo',
#        'Goias', 'Vitoria', 'Gremio', 'Vasco', 'Athletico-PR',
#        'Atletico-GO', 'Figueirense', 'America-MG', 'Coritiba', 'Bahia',
#        'Sport', 'Portuguesa', 'Nautico', 'Ponte Preta', 'Criciuma',
#        'Chapecoense', 'Joinville', 'Santa Cruz', 'Parana', 'Fortaleza',
#        'CSA', 'Bragantino', 'Juventude', 'Cuiaba'], dtype=object)

# %%
df_br['vencedor'].replace({'-': 'Empate'}, inplace=True)
df_br['vencedor'].unique()
# Out:
# array(['Empate', 'Palmeiras', 'Atletico-MG', 'Cruzeiro', 'Corinthians',
#        'Ceara', 'Guarani', 'Avai', 'Fluminense', 'Gremio Prudente',
#        'Botafogo-RJ', 'Internacional', 'Santos', 'Sao Paulo', 'Flamengo',
#        'Goias', 'Vitoria', 'Gremio', 'Vasco', 'Athletico-PR',
#        'Atletico-GO', 'Figueirense', 'America-MG', 'Coritiba', 'Bahia',
#        'Sport', 'Portuguesa', 'Nautico', 'Ponte Preta', 'Criciuma',
#        'Chapecoense', 'Joinville', 'Santa Cruz', 'Parana', 'Fortaleza',
#        'CSA', 'Bragantino', 'Juventude', 'Cuiaba'], dtype=object)
